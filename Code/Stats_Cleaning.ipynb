# %%
import pandas as pd
import numpy as np

ss = '/Users/samrioboli/DS440/Data/Rushing_Dataframe.csv'

df = pd.read_csv(ss)
df.head(5)
# Out:
#           Player     Rk   Tm  Age Pos   G  GS  Att  Yds  TD  1D    Lng    Y/A   Y/G  Fmb  Year
# 0  A.J. Brown     246.5  TEN  24   WR  29  24  5    70   1   3   28.00  12.50  2.30  1    2021
# 1  A.J. Feeley    135.0  MIA  27   QB  17  13  26   19   1   2   6.50   0.70   1.10  12   2004
# 2  A.J. Green     210.0  CIN  26   WR  44  44  11   93   0   5   15.67  7.03   2.03  6    2014
# 3  A.J. Jenkins   242.5  KAN  25   WR  25  3   4    4    0   0   2.50   1.00   0.10  1    2014
# 4  A.J. McCarron  158.0  CIN  25   QB  7   3   14   31   0   3   16.00  2.20   4.40  1    2015

# %% [markdown]
# Rounding stats to 2 decimals

# %%
#rounding to 2 decimals
for (columnName, columnData) in df.items():
    df[columnName] = df[columnName].apply(lambda x: round(x,2) if isinstance(x, float) else x)
df.head(5)
# Out:
#            Player      Rk   Tm  Age  Pos   G  GS  Intcpt  IntYds  IntTD    Lng  PD  FF  Fmb  FR  FumYds  FumTD    Sk  Comb  Solo  Ast  TFL  QBHits  Sfty  Year
# 0  Aaron Ross      398.00  NYG  28   DB   49  26  6       109     2      23.25  21  0   1    0   0       0      2.5   140   114   26   9    7       0     2010
# 1  Aaron Rouse     278.33  2TM  25   FS   41  18  4       173     1      44.33  11  0   0    0   0       0      1.0   143   110   33   4    3       0     2009
# 2  Aaron Williams  234.50  BUF  24   FS   49  44  6       69      0      15.00  28  3   1    0   0       0      0.0   222   162   60   4    0       0     2014
# 3  Adam Archuleta  71.00   STL  27   SS   58  55  2       24      0      6.00   18  3   2    4   162     2      11.5  340   297   43   26   0       0     2004
# 4  Adam Jones      246.33  DAL  25   LCB  39  34  4       130     1      27.67  30  2   12   6   22      0      1.0   148   121   27   5    1       0     2008

# %% [markdown]
# Remove irrelevant positions

# %%
df['Pos'].value_counts()
# Out:
# RB     371
# WR     368
# QB     191
# TE     45
# FB     39
# P      25
# DB     12
# LCB    3
# RCB    3
# NT     2
# K      2
# LG     2
# C      2
# LB     1
# RDE    1
# OL     1
# LLB    1
# SS     1
# RLB    1
# DT     1
# LS     1
# S      1
# 0      1
# FS     1
# Name: Pos, dtype: int64

# %%
posv = 'QB'
posdf = df[df['Pos'] == posv]
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', -1)
posdf
# Out:
# /var/folders/1v/4jjjwf412c72096krz_f0hv00000gn/T/ipykernel_20547/3642653598.py:5: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('max_colwidth', -1)
#                  Player      Rk   Tm  Age Pos   G  GS  Att   Yds  TD  1D    Lng   Y/A    Y/G  Fmb  Year
# 1     A.J. Feeley        135.00  MIA  27   QB  17  13  26   19    1   2   6.50   0.70  1.10   12   2004
# 4     A.J. McCarron      158.00  CIN  25   QB  7   3   14   31    0   3   16.00  2.20  4.40   1    2015
# 10    Aaron Rodgers      188.00  GNB  25   QB  23  16  67   254   4   26  12.00  4.20  8.80   13   2008
# 24    Alex Smith         105.33  SFO  23   QB  32  30  87   339   2   21  22.00  4.50  11.10  27   2007
# 42    Andrew Luck        77.75   IND  26   QB  55  55  222  1101  12  80  23.25  5.08  21.15  32   2015
# ...

# %%
df = df.replace('OLB','DE')

# %%
#IF NEED TO COMBINE POSITIONS TO MOVE TO OTHER DATASET
posvalt = 'QB'
posaltdf = posaltdf.append(df[df['Pos'] == posvalt])
posaltdf
# Out:
# /var/folders/1v/4jjjwf412c72096krz_f0hv00000gn/T/ipykernel_20547/650322317.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   posaltdf = posaltdf.append(df[df['Pos'] == posvalt])
#                  Player      Rk   Tm  Age Pos   G  GS  Intcpt  IntYds  IntTD    Lng  PD  FF  Fmb  FR  FumYds  FumTD  Sk  Comb  Solo  Ast  TFL  QBHits  Sfty  Year    Att     Yds    TD    1D   Y/A    Y/G
# 1     A.J. Feeley        135.00  MIA  27   QB  17  13 NaN     NaN     NaN     6.50  NaN NaN  12  NaN NaN     NaN    NaN NaN   NaN   NaN  NaN  NaN     NaN    2004  26.0   19.0    1.0   2.0   0.70  1.10
# 4     A.J. McCarron      158.00  CIN  25   QB  7   3  NaN     NaN     NaN     16.00 NaN NaN  1   NaN NaN     NaN    NaN NaN   NaN   NaN  NaN  NaN     NaN    2015  14.0   31.0    0.0   3.0   2.20  4.40
# ...

# %%
posaltdf = posaltdf.drop(columns=['FR', 'FumYds', 'FumTD', 'Sk', 'Comb', 'Solo', 'Ast', 'TFL', 'QBHits', 'Sfty', 'Year'])

# %%
posaltdf
# Out:
#                  Player    Lng  Fmb    Att     Yds    TD    1D   Y/A    Y/G
# 1     A.J. Feeley        6.50   12   26.0   19.0    1.0   2.0   0.70  1.10
# 4     A.J. McCarron      16.00  1    14.0   31.0    0.0   3.0   2.20  4.40
# 10    Aaron Rodgers      12.00  13   67.0   254.0   4.0   26.0  4.20  8.80
# 24    Alex Smith         22.00  27   87.0   339.0   2.0   21.0  4.50  11.10
# 42    Andrew Luck        23.25  32   222.0  1101.0  12.0  80.0  5.08  21.15
# ...           ...          ...  ..     ...     ...   ...   ...   ...    ...
# 1045  Tyler Thigpen      15.33  7    77.0   462.0   3.0   25.0  4.43  14.57
# 1047  Tyrod Taylor       13.75  0    27.0   136.0   1.0   10.0  3.60  7.35
# 1055  Vince Young        28.00  32   239.0  1255.0  12.0  79.0  4.85  23.88
# 1064  Will Grier         11.00  1    7.0    22.0    0.0   2.0   3.10  11.00
# 1072  Zach Mettenberger  6.50   8    14.0   12.0    1.0   3.0   0.85  0.85
#
# [191 rows x 9 columns]

# %%
ssqb = '/Users/samrioboli/DS440/Data/QB_Dataframe.csv'
dfqb = pd.read_csv(ssqb)

# %%
newqbdf = dfqb.merge(posaltdf, on='Player', how='left')

# %%
newqbdf
# Out:
#                 Player     Rk   Tm  Age Pos   G  GS  Win  Loss  Tie   Cmp  Att_x   Cmp%  Yds_x  TD_x   TD%  Int   Int%  1D_x  Lng_x  Y/A_x  AY/A    Y/C   Y/G_x   Rate   Sk  Yds.1    Sk%  NY/A  ANY/A  4QC  GWD  Year  Lng_y   Fmb  Att_y   Yds_y  TD_y  1D_y  Y/A_y  Y/G_y
# 0    A.J. Feeley        41.33  MIA  27   QB  18  13  7    6     0    287   524    60.30  3047   19    7.10  21   4.83   153   39.33  7.37   6.60  12.00  161.20  83.70  30   184    3.47   6.94  6.21   3    4    2004  6.50   12.0  26.0   19.0    1.0   2.0   0.70   1.10
# 1    A.J. McCarron      50.50  CIN  27   QB  10  3   2    1     0    86    133    58.20  920    6     2.50  2    0.85   50    46.50  5.95   6.05  10.10  72.00   80.25  13   72     7.95   4.92  5.04   0    0    2017  16.00  1.0   14.0   31.0    0.0   3.0   2.20   4.40
# ...

# %%
newqbdf.to_csv('/Users/samrioboli/DS440/Data/QBMerged_Dataframe.csv',index= False)

# %%
posaltdf = posaltdf.iloc[0:0]

# %%
df.drop(df.loc[df['Pos']==posv].index, inplace=True)
df['Pos'].value_counts()
# Out:
# LB      326
# RLB     55
# MLB     54
# LLB     43
# LILB    24
# RILB    21
# Name: Pos, dtype: int64

# %% [markdown]
# Drop dead columns

# %%
df
# Out:
#             Player      Rk   Tm  Age Pos    G  GS  Intcpt  IntYds  IntTD   Lng  PD  FF  Fmb  FR  FumYds  FumTD    Sk  Comb  Solo  Ast  TFL  QBHits  Sfty  Year
# 0    A.J. Epenesa   602.33  BUF  24   DE  43   3   0       0       0      0.00  7   2   0    1   0       0      9.0   44    32    12   12   23      0     2022
# 1    Aaron Kampman  349.25  GNB  26   DE  56   48  0       0       0      0.00  8   6   0    2   3       0      13.5  203   138   65   20   0       0     2005
# 2    Aaron Lynch    532.25  SFO  24   DE  44   19  0       0       0      0.00  7   0   0    1   0       0      15.0  83    64    19   29   46      0     2017
# 3    Aaron Maybin   781.25  NYJ  24   DE  48   1   0       0       0      0.00  0   5   0    0   0       0      6.0   37    27    10   5    10      0     2012
# 4    Aaron Schobel  276.00  BUF  27   DE  64   59  1       6       0      1.50  13  7   0    4   0       0      34.5  227   148   79   43   0       0     2004
# ...

# %%
del df[df.columns[0]]

# %%
df.to_csv(ss,index= False)
#df.to_csv(ss)

# %%
## MERGE EXTRA POSITIONS TO RIGHT DF
ss2 = '/Users/samrioboli/DS440/Data/DE_Dataframe.csv'
df2 = pd.read_csv(ss2)
df2
# Out:
#             Player      Rk   Tm  Age Pos    G  GS  Intcpt  IntYds  IntTD   Lng  PD  FF  Fmb  FR  FumYds  FumTD    Sk  Comb  Solo  Ast  TFL  QBHits  Sfty  Year
# 0    A.J. Epenesa   602.33  BUF  24   DE  43   3   0       0       0      0.00  7   2   0    1   0       0      9.0   44    32    12   12   23      0     2022
# 1    Aaron Kampman  349.25  GNB  26   DE  56   48  0       0       0      0.00  8   6   0    2   3       0      13.5  203   138   65   20   0       0     2005
# 2    Aaron Lynch    532.25  SFO  24   DE  44   19  0       0       0      0.00  7   0   0    1   0       0      15.0  83    64    19   29   46      0     2017
# 3    Aaron Maybin   781.25  NYJ  24   DE  48   1   0       0       0      0.00  0   5   0    0   0       0      6.0   37    27    10   5    10      0     2012
# 4    Aaron Schobel  276.00  BUF  27   DE  64   59  1       6       0      1.50  13  7   0    4   0       0      34.5  227   148   79   43   0       0     2004
# ...

# %%
df2 = df2.append(posaltdf)
df2
# Out:
# /var/folders/1v/4jjjwf412c72096krz_f0hv00000gn/T/ipykernel_20547/1529704410.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df2 = df2.append(posaltdf)
#                Player      Rk   Tm  Age   Pos   G  GS  Intcpt  IntYds  IntTD   Lng  PD  FF  Fmb  FR  FumYds  FumTD    Sk  Comb  Solo  Ast  TFL  QBHits  Sfty  Year
# 0    A.J. Epenesa      602.33  BUF  24   DE    43  3   0       0       0      0.00  7   2   0    1   0       0      9.0   44    32    12   12   23      0     2022
# 1    Aaron Kampman     349.25  GNB  26   DE    56  48  0       0       0      0.00  8   6   0    2   3       0      13.5  203   138   65   20   0       0     2005
# 2    Aaron Lynch       532.25  SFO  24   DE    44  19  0       0       0      0.00  7   0   0    1   0       0      15.0  83    64    19   29   46      0     2017
# ...

# %%
#FIX INDEXING AND EXTRA COLUMNS
df2.to_csv('/Users/samrioboli/DS440/Data/DEtest_Dataframe.csv',index= False)

# %%
sstest = '/Users/samrioboli/DS440/Data/DEtest_Dataframe.csv'
dftest = pd.read_csv(sstest)
dftest
# Out:
#                Player      Rk   Tm  Age   Pos   G  GS  Intcpt  IntYds  IntTD   Lng  PD  FF  Fmb  FR  FumYds  FumTD    Sk  Comb  Solo  Ast  TFL  QBHits  Sfty  Year
# 0    A.J. Epenesa      602.33  BUF  24   DE    43  3   0       0       0      0.00  7   2   0    1   0       0      9.0   44    32    12   12   23      0     2022
# 1    Aaron Kampman     349.25  GNB  26   DE    56  48  0       0       0      0.00  8   6   0    2   3       0      13.5  203   138   65   20   0       0     2005
# 2    Aaron Lynch       532.25  SFO  24   DE    44  19  0       0       0      0.00  7   0   0    1   0       0      15.0  83    64    19   29   46      0     2017
# 3    Aaron Maybin      781.25  NYJ  24   DE    48  1   0       0       0      0.00  0   5   0    0   0       0      6.0   37    27    10   5    10      0     2012
# 4    Aaron Schobel     276.00  BUF  27   DE    64  59  1       6       0      1.50  13  7   0    4   0       0      34.5  227   148   79   43   0       0     2004
# ...

# %%
dftest.to_csv(ss2,index= False)
